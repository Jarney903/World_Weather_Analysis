# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
#3 Create a new set of 2,000 random latitudes and longitudes.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

#How long? = 2000
len(lats)
len(lngs)

#Takes iterable or containers and returns a single iterator object,
lat_lngs = zip(lats, lngs)
lat_lngs

# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)
#coordinates

# %%
#4  Get the nearest city using the citipy module.

# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 788

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
#print(url)

# %%
# # Create an endpoint URL for a city.
# city_url = url + "&q=" + "Boston"
# city_weather = requests.get(city_url)
# city_weather.json()

# %%
# # Get the JSON data.
# boston_data = city_weather.json()
# boston_data["weather"][0]['description']
# Out:
# 'overcast clouds'

# %%
#5 Perform an API call with the OpenWeatherMap.

# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i in range(len(cities)):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + cities[i]

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
  

### The following information from the API call:
# Latitude and longitude
# Maximum temperature
# Percent humidity
# Percent cloudiness
# Wind speed
# Weather description (for example, clouds, fog, light rain, clear sky)
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]['description']
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Current Description": city_description })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 16 | avera
# Processing Record 2 of Set 16 | rabo de peixe
# Processing Record 3 of Set 16 | busselton
# Processing Record 4 of Set 16 | grand river south east
# City not found. Skipping...
# Processing Record 5 of Set 16 | springfield
# Processing Record 6 of Set 16 | puerto ayora
# Processing Record 7 of Set 16 | roald
# Processing Record 8 of Set 16 | antofagasta
# Processing Record 9 of Set 16 | foki
# Processing Record 10 of Set 16 | kapaa
# Processing Record 11 of Set 16 | portland
# Processing Record 12 of Set 16 | jackson
# Processing Record 13 of Set 16 | comodoro rivadavia
# Processing Record 14 of Set 16 | taolanaro
# City not found. Skipping...
# Processing Record 15 of Set 16 | chapais
# Processing Record 16 of Set 16 | punta arenas
# Processing Record 17 of Set 16 | shetpe
# Processing Record 18 of Set 16 | bluff
# Processing Record 19 of Set 16 | nikolskoye
# Processing Record 20 of Set 16 | aklavik
# Processing Record 21 of Set 16 | esperance
# Processing Record 22 of Set 16 | geraldton
# Processing Record 23 of Set 16 | yellowknife
# Processing Record 24 of Set 16 | new norfolk
# Processing Record 25 of Set 16 | mataura
# Processing Record 26 of Set 16 | utiroa
# City not found. Skipping...
# Processing Record 27 of Set 16 | hermanus
# Processing Record 28 of Set 16 | lebu
# Processing Record 29 of Set 16 | gushikawa
# Processing Record 30 of Set 16 | hirara
# Processing Record 31 of Set 16 | qaanaaq
# Processing Record 32 of Set 16 | ushuaia
# Processing Record 33 of Set 16 | victoria
# Processing Record 34 of Set 16 | klaksvik
# Processing Record 35 of Set 16 | sola
# Processing Record 36 of Set 16 | alice springs
# Processing Record 37 of Set 16 | pisco
# Processing Record 38 of Set 16 | sudbury
# Processing Record 39 of Set 16 | nabire
# Processing Record 40 of Set 16 | haines junction
# Processing Record 41 of Set 16 | bosobolo
# Processing Record 42 of Set 16 | oxelosund
# Processing Record 43 of Set 16 | saldanha
# Processing Record 44 of Set 16 | talaja
# Processing Record 45 of Set 16 | kodiak
# Processing Record 46 of Set 16 | west wendover
# Processing Record 47 of Set 16 | georgetown
# Processing Record 48 of Set 16 | camacha
# Processing Record 49 of Set 16 | eenhana
# Processing Record 50 of Set 16 | chokurdakh
# Processing Record 1 of Set 17 | bedele
# Processing Record 2 of Set 17 | rikitea
# Processing Record 3 of Set 17 | cidreira
# Processing Record 4 of Set 17 | ahuimanu
# Processing Record 5 of Set 17 | ribeira grande
# Processing Record 6 of Set 17 | saint-joseph
# Processing Record 7 of Set 17 | komsomolskiy
# Processing Record 8 of Set 17 | bambous virieux
# Processing Record 9 of Set 17 | east london
# Processing Record 10 of Set 17 | berlevag
# Processing Record 11 of Set 17 | adre
# Processing Record 12 of Set 17 | port elizabeth
# Processing Record 13 of Set 17 | sampit
# Processing Record 14 of Set 17 | castro
# Processing Record 15 of Set 17 | tahta
# Processing Record 16 of Set 17 | san patricio
# Processing Record 17 of Set 17 | belushya guba
# City not found. Skipping...
# Processing Record 18 of Set 17 | thompson
# Processing Record 19 of Set 17 | mehamn
# Processing Record 20 of Set 17 | dunedin
# Processing Record 21 of Set 17 | port macquarie
# Processing Record 22 of Set 17 | jamestown
# Processing Record 23 of Set 17 | muros
# Processing Record 24 of Set 17 | maracacume
# Processing Record 25 of Set 17 | lompoc
# Processing Record 26 of Set 17 | santa isabel do rio negro
# Processing Record 27 of Set 17 | arraial do cabo
# Processing Record 28 of Set 17 | belmonte
# Processing Record 29 of Set 17 | tilichiki
# Processing Record 30 of Set 17 | atuona
# Processing Record 31 of Set 17 | tasiilaq
# Processing Record 32 of Set 17 | mogadishu
# Processing Record 33 of Set 17 | hilo
# Processing Record 34 of Set 17 | houma
# Processing Record 35 of Set 17 | kahului
# Processing Record 36 of Set 17 | ndende
# Processing Record 37 of Set 17 | khatanga
# Processing Record 38 of Set 17 | port alfred
# Processing Record 39 of Set 17 | albany
# Processing Record 40 of Set 17 | mahebourg
# Processing Record 41 of Set 17 | saint-pierre
# Processing Record 42 of Set 17 | bredasdorp
# Processing Record 43 of Set 17 | casa grande
# Processing Record 44 of Set 17 | asau
# Processing Record 45 of Set 17 | horta
# Processing Record 46 of Set 17 | port lincoln
# Processing Record 47 of Set 17 | le port
# Processing Record 48 of Set 17 | tarudant
# City not found. Skipping...
# Processing Record 49 of Set 17 | waipawa
# Processing Record 50 of Set 17 | ballina
# Processing Record 1 of Set 18 | suntar
# Processing Record 2 of Set 18 | mar del plata
# Processing Record 3 of Set 18 | mocuba
# Processing Record 4 of Set 18 | torbay
# Processing Record 5 of Set 18 | sakakah
# Processing Record 6 of Set 18 | hasaki
# Processing Record 7 of Set 18 | qaqortoq
# Processing Record 8 of Set 18 | saskylakh
# Processing Record 9 of Set 18 | ampanihy
# Processing Record 10 of Set 18 | faanui
# Processing Record 11 of Set 18 | hobart
# Processing Record 12 of Set 18 | verdalsora
# City not found. Skipping...
# Processing Record 13 of Set 18 | talnakh
# Processing Record 14 of Set 18 | cape town
# Processing Record 15 of Set 18 | labuhan
# Processing Record 16 of Set 18 | balod
# Processing Record 17 of Set 18 | kupang
# Processing Record 18 of Set 18 | dabwali
# Processing Record 19 of Set 18 | diamantino
# Processing Record 20 of Set 18 | sentyabrskiy
# City not found. Skipping...
# Processing Record 21 of Set 18 | aykhal
# Processing Record 22 of Set 18 | mys shmidta
# City not found. Skipping...
# Processing Record 23 of Set 18 | bethel
# Processing Record 24 of Set 18 | goma
# Processing Record 25 of Set 18 | arlit
# Processing Record 26 of Set 18 | nhulunbuy
# Processing Record 27 of Set 18 | maragogi
# Processing Record 28 of Set 18 | ruteng
# Processing Record 29 of Set 18 | diksmuide
# Processing Record 30 of Set 18 | laguna
# Processing Record 31 of Set 18 | kjollefjord
# Processing Record 32 of Set 18 | yarada
# Processing Record 33 of Set 18 | vila do maio
# Processing Record 34 of Set 18 | amderma
# City not found. Skipping...
# Processing Record 35 of Set 18 | hithadhoo
# Processing Record 36 of Set 18 | marsh harbour
# Processing Record 37 of Set 18 | sinnamary
# Processing Record 38 of Set 18 | westport
# Processing Record 39 of Set 18 | shieli
# Processing Record 40 of Set 18 | barrow
# Processing Record 41 of Set 18 | butaritari
# Processing Record 42 of Set 18 | dali
# Processing Record 43 of Set 18 | ilulissat
# Processing Record 44 of Set 18 | saint george
# Processing Record 45 of Set 18 | mrirt
# City not found. Skipping...
# Processing Record 46 of Set 18 | sao joao da barra
# Processing Record 47 of Set 18 | kaitangata
# Processing Record 48 of Set 18 | santa cruz
# Processing Record 49 of Set 18 | siparia
# Processing Record 50 of Set 18 | ramnagar
# Processing Record 1 of Set 19 | gayeri
# Processing Record 2 of Set 19 | vaini
# Processing Record 3 of Set 19 | amga
# Processing Record 4 of Set 19 | novyy urengoy
# Processing Record 5 of Set 19 | caconda
# Processing Record 6 of Set 19 | bubaque
# Processing Record 7 of Set 19 | upernavik
# Processing Record 8 of Set 19 | sao filipe
# Processing Record 9 of Set 19 | treinta y tres
# Processing Record 10 of Set 19 | yulara
# Processing Record 11 of Set 19 | dipkarpaz
# City not found. Skipping...
# Processing Record 12 of Set 19 | moindou
# Processing Record 13 of Set 19 | nizhneyansk
# City not found. Skipping...
# Processing Record 14 of Set 19 | avarua
# Processing Record 15 of Set 19 | farmington
# Processing Record 16 of Set 19 | dikson
# Processing Record 17 of Set 19 | airai
# Processing Record 18 of Set 19 | beloha
# Processing Record 19 of Set 19 | road town
# Processing Record 20 of Set 19 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 21 of Set 19 | port hedland
# Processing Record 22 of Set 19 | kuopio
# Processing Record 23 of Set 19 | mardin
# Processing Record 24 of Set 19 | vostok
# Processing Record 25 of Set 19 | togur
# Processing Record 26 of Set 19 | lipin bor
# Processing Record 27 of Set 19 | bako
# Processing Record 28 of Set 19 | mabaruma
# Processing Record 29 of Set 19 | kaeo
# Processing Record 30 of Set 19 | borogontsy
# Processing Record 31 of Set 19 | rudsar
# Processing Record 32 of Set 19 | emba
# Processing Record 33 of Set 19 | richards bay
# Processing Record 34 of Set 19 | san policarpo
# Processing Record 35 of Set 19 | wuan
# Processing Record 36 of Set 19 | boca do acre
# Processing Record 37 of Set 19 | muravlenko
# Processing Record 38 of Set 19 | quelimane
# Processing Record 39 of Set 19 | kantunilkin
# Processing Record 40 of Set 19 | tocopilla
# Processing Record 41 of Set 19 | camabatela
# Processing Record 42 of Set 19 | saint-philippe
# Processing Record 43 of Set 19 | harlingen
# Processing Record 44 of Set 19 | kajaani
# Processing Record 45 of Set 19 | altay
# Processing Record 46 of Set 19 | verkh-usugli
# Processing Record 47 of Set 19 | bolungarvik
# City not found. Skipping...
# Processing Record 48 of Set 19 | clyde river
# Processing Record 49 of Set 19 | meyungs
# City not found. Skipping...
# Processing Record 50 of Set 19 | vao
# Processing Record 1 of Set 20 | san quintin
# Processing Record 2 of Set 20 | otjimbingwe
# Processing Record 3 of Set 20 | sitka
# Processing Record 4 of Set 20 | gigmoto
# Processing Record 5 of Set 20 | ponta do sol
# Processing Record 6 of Set 20 | tsihombe
# City not found. Skipping...
# Processing Record 7 of Set 20 | moron
# Processing Record 8 of Set 20 | zhanakorgan
# Processing Record 9 of Set 20 | college
# Processing Record 10 of Set 20 | shkotovo-26
# City not found. Skipping...
# Processing Record 11 of Set 20 | tuktoyaktuk
# Processing Record 12 of Set 20 | tawzar
# City not found. Skipping...
# Processing Record 13 of Set 20 | touros
# Processing Record 14 of Set 20 | hailar
# Processing Record 15 of Set 20 | lagoa
# Processing Record 16 of Set 20 | taree
# Processing Record 17 of Set 20 | coos bay
# Processing Record 18 of Set 20 | san francisco del mar
# Processing Record 19 of Set 20 | nganjuk
# Processing Record 20 of Set 20 | paamiut
# Processing Record 21 of Set 20 | kurumkan
# Processing Record 22 of Set 20 | alta floresta
# Processing Record 23 of Set 20 | huarmey
# Processing Record 24 of Set 20 | saint anthony
# Processing Record 25 of Set 20 | ken caryl
# Processing Record 26 of Set 20 | barentsburg
# City not found. Skipping...
# Processing Record 27 of Set 20 | marcona
# City not found. Skipping...
# Processing Record 28 of Set 20 | san lorenzo
# Processing Record 29 of Set 20 | palabuhanratu
# City not found. Skipping...
# Processing Record 30 of Set 20 | yuanping
# Processing Record 31 of Set 20 | newport
# Processing Record 32 of Set 20 | celestun
# Processing Record 33 of Set 20 | uruzgan
# Processing Record 34 of Set 20 | brindisi
# Processing Record 35 of Set 20 | fare
# Processing Record 36 of Set 20 | kavieng
# Processing Record 37 of Set 20 | tiszavasvari
# Processing Record 38 of Set 20 | severo-kurilsk
# Processing Record 39 of Set 20 | naini tal
# Processing Record 40 of Set 20 | udachnyy
# Processing Record 41 of Set 20 | peniche
# Processing Record 42 of Set 20 | general pico
# Processing Record 43 of Set 20 | longyearbyen
# Processing Record 44 of Set 20 | carnarvon
# Processing Record 45 of Set 20 | praia da vitoria
# Processing Record 46 of Set 20 | acapulco
# Processing Record 47 of Set 20 | northam
# Processing Record 48 of Set 20 | souillac
# Processing Record 49 of Set 20 | ust-omchug
# Processing Record 50 of Set 20 | marzuq
# Processing Record 1 of Set 21 | mezen
# Processing Record 2 of Set 21 | tumannyy
# City not found. Skipping...
# Processing Record 3 of Set 21 | london
# Processing Record 4 of Set 21 | nemuro
# Processing Record 5 of Set 21 | maumere
# Processing Record 6 of Set 21 | dakar
# Processing Record 7 of Set 21 | karkaralinsk
# City not found. Skipping...
# Processing Record 8 of Set 21 | tiksi
# Processing Record 9 of Set 21 | samusu
# City not found. Skipping...
# Processing Record 10 of Set 21 | aripuana
# Processing Record 11 of Set 21 | namibe
# Processing Record 12 of Set 21 | ikryanoye
# Processing Record 13 of Set 21 | ayan
# Processing Record 14 of Set 21 | hashtrud
# Processing Record 15 of Set 21 | luau
# Processing Record 16 of Set 21 | leningradskiy
# Processing Record 17 of Set 21 | norsup
# Processing Record 18 of Set 21 | penzance
# Processing Record 19 of Set 21 | zhigansk
# Processing Record 20 of Set 21 | senanga
# Processing Record 21 of Set 21 | xichang
# Processing Record 22 of Set 21 | padang
# Processing Record 23 of Set 21 | vestmanna
# Processing Record 24 of Set 21 | teguise
# Processing Record 25 of Set 21 | ilorin
# Processing Record 26 of Set 21 | plouzane
# Processing Record 27 of Set 21 | berdigestyakh
# Processing Record 28 of Set 21 | ancud
# Processing Record 29 of Set 21 | bathsheba
# Processing Record 30 of Set 21 | gold coast
# Processing Record 31 of Set 21 | umzimvubu
# City not found. Skipping...
# Processing Record 32 of Set 21 | hit
# Processing Record 33 of Set 21 | charlottesville
# Processing Record 34 of Set 21 | vaitupu
# City not found. Skipping...
# Processing Record 35 of Set 21 | quatre cocos
# Processing Record 36 of Set 21 | shingu
# Processing Record 37 of Set 21 | rocha
# Processing Record 38 of Set 21 | yumen
# Processing Record 39 of Set 21 | egvekinot
# Processing Record 40 of Set 21 | cherskiy
# Processing Record 41 of Set 21 | bilma
# Processing Record 42 of Set 21 | rawson
# Processing Record 43 of Set 21 | sindou
# Processing Record 44 of Set 21 | norman wells
# Processing Record 45 of Set 21 | rolim de moura
# City not found. Skipping...
# Processing Record 46 of Set 21 | zhangye
# Processing Record 47 of Set 21 | necochea
# Processing Record 48 of Set 21 | luderitz
# Processing Record 49 of Set 21 | nadadores
# Processing Record 50 of Set 21 | bay roberts
# Processing Record 1 of Set 22 | provideniya
# Processing Record 2 of Set 22 | cabo san lucas
# Processing Record 3 of Set 22 | nurobod
# Processing Record 4 of Set 22 | leua
# Processing Record 5 of Set 22 | shimoda
# Processing Record 6 of Set 22 | pundaguitan
# Processing Record 7 of Set 22 | naze
# Processing Record 8 of Set 22 | ulaanbaatar
# Processing Record 9 of Set 22 | te anau
# Processing Record 10 of Set 22 | murray bridge
# Processing Record 11 of Set 22 | maneadero
# Processing Record 12 of Set 22 | san martin
# Processing Record 13 of Set 22 | jishou
# Processing Record 14 of Set 22 | harper
# Processing Record 15 of Set 22 | yar-sale
# Processing Record 16 of Set 22 | novokayakent
# Processing Record 17 of Set 22 | henties bay
# Processing Record 18 of Set 22 | maceio
# Processing Record 19 of Set 22 | bama
# Processing Record 20 of Set 22 | coihaique
# Processing Record 21 of Set 22 | silver city
# Processing Record 22 of Set 22 | petrolina
# Processing Record 23 of Set 22 | maine-soroa
# Processing Record 24 of Set 22 | tura
# Processing Record 25 of Set 22 | isiro
# Processing Record 26 of Set 22 | norfolk
# Processing Record 27 of Set 22 | tuatapere
# Processing Record 28 of Set 22 | salinas
# Processing Record 29 of Set 22 | port hardy
# Processing Record 30 of Set 22 | cockburn town
# Processing Record 31 of Set 22 | svetlogorsk
# Processing Record 32 of Set 22 | motygino
# Processing Record 33 of Set 22 | baikunthpur
# Processing Record 34 of Set 22 | huanren
# Processing Record 35 of Set 22 | champerico
# Processing Record 36 of Set 22 | vila franca do campo
# Processing Record 37 of Set 22 | bengkulu
# Processing Record 38 of Set 22 | kolondieba
# Processing Record 39 of Set 22 | kibala
# Processing Record 40 of Set 22 | caibarien
# Processing Record 41 of Set 22 | poronaysk
# Processing Record 42 of Set 22 | superior
# Processing Record 43 of Set 22 | bay city
# Processing Record 44 of Set 22 | codrington
# Processing Record 45 of Set 22 | salalah
# Processing Record 46 of Set 22 | morti
# City not found. Skipping...
# Processing Record 47 of Set 22 | wexford
# Processing Record 48 of Set 22 | lakselv
# Processing Record 49 of Set 22 | poum
# Processing Record 50 of Set 22 | kruisfontein
# Processing Record 1 of Set 23 | rio pardo
# Processing Record 2 of Set 23 | piterka
# Processing Record 3 of Set 23 | port keats
# Processing Record 4 of Set 23 | cap malheureux
# Processing Record 5 of Set 23 | ksenyevka
# City not found. Skipping...
# Processing Record 6 of Set 23 | carndonagh
# Processing Record 7 of Set 23 | okha
# Processing Record 8 of Set 23 | ganta
# Processing Record 9 of Set 23 | sao gabriel da cachoeira
# Processing Record 10 of Set 23 | sobolevo
# Processing Record 11 of Set 23 | trabzon
# Processing Record 12 of Set 23 | faribault
# Processing Record 13 of Set 23 | marion
# Processing Record 14 of Set 23 | la asuncion
# Processing Record 15 of Set 23 | krasnousolskiy
# City not found. Skipping...
# Processing Record 16 of Set 23 | filingue
# Processing Record 17 of Set 23 | tiznit
# Processing Record 18 of Set 23 | tingo maria
# Processing Record 19 of Set 23 | casablanca
# Processing Record 20 of Set 23 | roros
# Processing Record 21 of Set 23 | pervomayskiy
# Processing Record 22 of Set 23 | atambua
# Processing Record 23 of Set 23 | san juan bautista
# Processing Record 24 of Set 23 | meulaboh
# Processing Record 25 of Set 23 | sokoto
# Processing Record 26 of Set 23 | bafut
# Processing Record 27 of Set 23 | hukuntsi
# Processing Record 28 of Set 23 | malwan
# City not found. Skipping...
# Processing Record 29 of Set 23 | thinadhoo
# Processing Record 30 of Set 23 | kurkino
# Processing Record 31 of Set 23 | rancho palos verdes
# Processing Record 32 of Set 23 | camopi
# Processing Record 33 of Set 23 | kuching
# Processing Record 34 of Set 23 | juneau
# Processing Record 35 of Set 23 | alcaniz
# Processing Record 36 of Set 23 | kendari
# Processing Record 37 of Set 23 | sao joaquim
# Processing Record 38 of Set 23 | vila velha
# Processing Record 39 of Set 23 | playas
# Processing Record 40 of Set 23 | dingle
# Processing Record 41 of Set 23 | neijiang
# Processing Record 42 of Set 23 | hami
# Processing Record 43 of Set 23 | along
# Processing Record 44 of Set 23 | nome
# Processing Record 45 of Set 23 | villa del rosario
# Processing Record 46 of Set 23 | novosheshminsk
# Processing Record 47 of Set 23 | kasongo-lunda
# Processing Record 48 of Set 23 | waitati
# Processing Record 49 of Set 23 | vestmannaeyjar
# Processing Record 50 of Set 23 | katsuura
# Processing Record 1 of Set 24 | belaya gora
# Processing Record 2 of Set 24 | san cristobal
# Processing Record 3 of Set 24 | grindavik
# Processing Record 4 of Set 24 | pato branco
# Processing Record 5 of Set 24 | yarmouth
# Processing Record 6 of Set 24 | kedrovyy
# Processing Record 7 of Set 24 | funtua
# Processing Record 8 of Set 24 | linchuan
# City not found. Skipping...
# Processing Record 9 of Set 24 | vardo
# Processing Record 10 of Set 24 | rosarito
# Processing Record 11 of Set 24 | teknaf
# Processing Record 12 of Set 24 | fenyi
# Processing Record 13 of Set 24 | xinzhi
# Processing Record 14 of Set 24 | los llanos de aridane
# Processing Record 15 of Set 24 | meihekou
# Processing Record 16 of Set 24 | hermosillo
# Processing Record 17 of Set 24 | shebekino
# Processing Record 18 of Set 24 | barkot
# Processing Record 19 of Set 24 | fort smith
# Processing Record 20 of Set 24 | oiso
# Processing Record 21 of Set 24 | west point
# Processing Record 22 of Set 24 | torrington
# Processing Record 23 of Set 24 | maralal
# Processing Record 24 of Set 24 | barcelos
# Processing Record 25 of Set 24 | ahipara
# Processing Record 26 of Set 24 | amritsar
# Processing Record 27 of Set 24 | pangnirtung
# Processing Record 28 of Set 24 | burica
# City not found. Skipping...
# Processing Record 29 of Set 24 | nanortalik
# Processing Record 30 of Set 24 | beringovskiy
# Processing Record 31 of Set 24 | ledyard
# Processing Record 32 of Set 24 | nouadhibou
# Processing Record 33 of Set 24 | nushki
# Processing Record 34 of Set 24 | beyneu
# Processing Record 35 of Set 24 | lorengau
# Processing Record 36 of Set 24 | hualmay
# Processing Record 37 of Set 24 | zolotukhino
# Processing Record 38 of Set 24 | mathathane
# Processing Record 39 of Set 24 | puerto pinasco
# City not found. Skipping...
# Processing Record 40 of Set 24 | jiaojiang
# Processing Record 41 of Set 24 | abashiri
# Processing Record 42 of Set 24 | ascension
# Processing Record 43 of Set 24 | marawi
# Processing Record 44 of Set 24 | andselv
# City not found. Skipping...
# Processing Record 45 of Set 24 | luanshya
# Processing Record 46 of Set 24 | narsaq
# Processing Record 47 of Set 24 | warqla
# City not found. Skipping...
# Processing Record 48 of Set 24 | pevek
# Processing Record 49 of Set 24 | makakilo city
# Processing Record 50 of Set 24 | temaraia
# City not found. Skipping...
# Processing Record 1 of Set 25 | christchurch
# Processing Record 2 of Set 25 | chuy
# Processing Record 3 of Set 25 | iqaluit
# Processing Record 4 of Set 25 | kazalinsk
# City not found. Skipping...
# Processing Record 5 of Set 25 | bilibino
# Processing Record 6 of Set 25 | knysna
# Processing Record 7 of Set 25 | dukat
# Processing Record 8 of Set 25 | muzhi
# Processing Record 9 of Set 25 | artyk
# City not found. Skipping...
# Processing Record 10 of Set 25 | safaga
# Processing Record 11 of Set 25 | sistranda
# Processing Record 12 of Set 25 | taldan
# Processing Record 13 of Set 25 | hammerfest
# Processing Record 14 of Set 25 | pangody
# Processing Record 15 of Set 25 | saurimo
# Processing Record 16 of Set 25 | hihifo
# City not found. Skipping...
# Processing Record 17 of Set 25 | abu dhabi
# Processing Record 18 of Set 25 | husavik
# Processing Record 19 of Set 25 | verkhoyansk
# Processing Record 20 of Set 25 | yerofey pavlovich
# Processing Record 21 of Set 25 | roquetas de mar
# Processing Record 22 of Set 25 | caravelas
# Processing Record 23 of Set 25 | shenjiamen
# Processing Record 24 of Set 25 | erzin
# Processing Record 25 of Set 25 | lennec
# Processing Record 26 of Set 25 | brae
# Processing Record 27 of Set 25 | isfana
# Processing Record 28 of Set 25 | port augusta
# Processing Record 29 of Set 25 | safford
# Processing Record 30 of Set 25 | ekhabi
# Processing Record 31 of Set 25 | termoli
# Processing Record 32 of Set 25 | stare mesto
# Processing Record 33 of Set 25 | merauke
# Processing Record 34 of Set 25 | socorro
# Processing Record 35 of Set 25 | tula
# Processing Record 36 of Set 25 | ust-maya
# Processing Record 37 of Set 25 | krasnoborsk
# Processing Record 38 of Set 25 | pakxan
# Processing Record 39 of Set 25 | santo amaro das brotas
# Processing Record 40 of Set 25 | sao jose da coroa grande
# Processing Record 41 of Set 25 | segou
# Processing Record 42 of Set 25 | manadhoo
# Processing Record 43 of Set 25 | aksehir
# Processing Record 44 of Set 25 | steinbach
# Processing Record 45 of Set 25 | xai-xai
# Processing Record 46 of Set 25 | andevoranto
# City not found. Skipping...
# Processing Record 47 of Set 25 | tomatlan
# Processing Record 48 of Set 25 | gustrow
# Processing Record 49 of Set 25 | auka
# Processing Record 50 of Set 25 | north platte
# Processing Record 1 of Set 26 | constitucion
# Processing Record 2 of Set 26 | antipovka
# Processing Record 3 of Set 26 | olafsvik
# Processing Record 4 of Set 26 | fairbanks
# Processing Record 5 of Set 26 | zalantun
# Processing Record 6 of Set 26 | santa rosalia
# Processing Record 7 of Set 26 | storforshei
# Processing Record 8 of Set 26 | guerrero negro
# Processing Record 9 of Set 26 | limon
# Processing Record 10 of Set 26 | lewisporte
# Processing Record 11 of Set 26 | benguela
# Processing Record 12 of Set 26 | sulangan
# Processing Record 13 of Set 26 | margate
# Processing Record 14 of Set 26 | waingapu
# Processing Record 15 of Set 26 | manbij
# Processing Record 16 of Set 26 | auki
# Processing Record 17 of Set 26 | atyrau
# Processing Record 18 of Set 26 | shahr-e kord
# Processing Record 19 of Set 26 | faya
# Processing Record 20 of Set 26 | karamay
# City not found. Skipping...
# Processing Record 21 of Set 26 | tiarei
# Processing Record 22 of Set 26 | cayenne
# Processing Record 23 of Set 26 | hamilton
# Processing Record 24 of Set 26 | sorland
# Processing Record 25 of Set 26 | broome
# Processing Record 26 of Set 26 | petropavlovsk-kamchatskiy
# Processing Record 27 of Set 26 | soyo
# Processing Record 28 of Set 26 | carmarthen
# Processing Record 29 of Set 26 | korla
# Processing Record 30 of Set 26 | kondinskoye
# Processing Record 31 of Set 26 | lublin
# Processing Record 32 of Set 26 | ixtapa
# Processing Record 33 of Set 26 | ouadda
# Processing Record 34 of Set 26 | wad rawah
# Processing Record 35 of Set 26 | muzquiz
# City not found. Skipping...
# Processing Record 36 of Set 26 | lagunas
# Processing Record 37 of Set 26 | toliary
# City not found. Skipping...
# Processing Record 38 of Set 26 | oia
# Processing Record 39 of Set 26 | nantucket
# Processing Record 40 of Set 26 | viligili
# City not found. Skipping...
# Processing Record 41 of Set 26 | zabol
# Processing Record 42 of Set 26 | salina
# Processing Record 43 of Set 26 | palu
# Processing Record 44 of Set 26 | eyl
# Processing Record 45 of Set 26 | labuan
# Processing Record 46 of Set 26 | djougou
# Processing Record 47 of Set 26 | makung
# City not found. Skipping...
# Processing Record 48 of Set 26 | lieksa
# Processing Record 49 of Set 26 | corinth
# Processing Record 50 of Set 26 | yerbogachen
# Processing Record 1 of Set 27 | xining
# Processing Record 2 of Set 27 | gimli
# Processing Record 3 of Set 27 | severobaykalsk
# Processing Record 4 of Set 27 | evensk
# Processing Record 5 of Set 27 | marrakesh
# Processing Record 6 of Set 27 | marsabit
# Processing Record 7 of Set 27 | natal
# Processing Record 8 of Set 27 | donegal
# Processing Record 9 of Set 27 | nadapuram
# Processing Record 10 of Set 27 | falkoping
# City not found. Skipping...
# Processing Record 11 of Set 27 | mirnyy
# Processing Record 12 of Set 27 | amapa
# Processing Record 13 of Set 27 | skelleftea
# Processing Record 14 of Set 27 | labutta
# City not found. Skipping...
# Processing Record 15 of Set 27 | attawapiskat
# City not found. Skipping...
# Processing Record 16 of Set 27 | flin flon
# Processing Record 17 of Set 27 | giyani
# Processing Record 18 of Set 27 | xiuyan
# Processing Record 19 of Set 27 | svetlaya
# Processing Record 20 of Set 27 | santa rosa
# Processing Record 21 of Set 27 | rio gallegos
# Processing Record 22 of Set 27 | alotau
# City not found. Skipping...
# Processing Record 23 of Set 27 | ebebiyin
# Processing Record 24 of Set 27 | ishigaki
# Processing Record 25 of Set 27 | ginda
# Processing Record 26 of Set 27 | turukhansk
# Processing Record 27 of Set 27 | eskil
# Processing Record 28 of Set 27 | bonnyville
# Processing Record 29 of Set 27 | wangaratta
# Processing Record 30 of Set 27 | bahia blanca
# Processing Record 31 of Set 27 | keizer
# Processing Record 32 of Set 27 | maizuru
# Processing Record 33 of Set 27 | manga
# Processing Record 34 of Set 27 | arandis
# Processing Record 35 of Set 27 | mount isa
# Processing Record 36 of Set 27 | araouane
# Processing Record 37 of Set 27 | armidale
# Processing Record 38 of Set 27 | puerto escondido
# Processing Record 39 of Set 27 | kampot
# Processing Record 40 of Set 27 | goderich
# Processing Record 41 of Set 27 | hofn
# Processing Record 42 of Set 27 | paytug
# City not found. Skipping...
# Processing Record 43 of Set 27 | nelson bay
# Processing Record 44 of Set 27 | litovko
# Processing Record 45 of Set 27 | mago
# Processing Record 46 of Set 27 | acarau
# Processing Record 47 of Set 27 | zakamensk
# Processing Record 48 of Set 27 | gayny
# Processing Record 49 of Set 27 | danville
# Processing Record 50 of Set 27 | matay
# Processing Record 1 of Set 28 | alamogordo
# Processing Record 2 of Set 28 | ikorodu
# Processing Record 3 of Set 28 | la romana
# Processing Record 4 of Set 28 | deputatskiy
# Processing Record 5 of Set 28 | payo
# Processing Record 6 of Set 28 | lucapa
# Processing Record 7 of Set 28 | nguiu
# City not found. Skipping...
# Processing Record 8 of Set 28 | fortuna
# Processing Record 9 of Set 28 | sao caetano de odivelas
# Processing Record 10 of Set 28 | grand gaube
# Processing Record 11 of Set 28 | samarai
# Processing Record 12 of Set 28 | malkangiri
# Processing Record 13 of Set 28 | pombas
# Processing Record 14 of Set 28 | baiyin
# Processing Record 15 of Set 28 | kloulklubed
# Processing Record 16 of Set 28 | lamar
# Processing Record 17 of Set 28 | teahupoo
# Processing Record 18 of Set 28 | cozumel
# Processing Record 19 of Set 28 | barra do garcas
# Processing Record 20 of Set 28 | estelle
# Processing Record 21 of Set 28 | upington
# Processing Record 22 of Set 28 | cairns
# Processing Record 23 of Set 28 | norilsk
# Processing Record 24 of Set 28 | bang saphan
# Processing Record 25 of Set 28 | tual
# Processing Record 26 of Set 28 | malmesbury
# Processing Record 27 of Set 28 | abu jubayhah
# City not found. Skipping...
# Processing Record 28 of Set 28 | governador dix-sept rosado
# Processing Record 29 of Set 28 | sokoni
# Processing Record 30 of Set 28 | saryg-sep
# Processing Record 31 of Set 28 | manggar
# Processing Record 32 of Set 28 | koslan
# Processing Record 33 of Set 28 | port-gentil
# Processing Record 34 of Set 28 | balkhash
# Processing Record 35 of Set 28 | havre-saint-pierre
# Processing Record 36 of Set 28 | areosa
# Processing Record 37 of Set 28 | honiara
# Processing Record 38 of Set 28 | monrovia
# Processing Record 39 of Set 28 | bowen
# Processing Record 40 of Set 28 | whitefish
# Processing Record 41 of Set 28 | jiaozuo
# Processing Record 42 of Set 28 | rawannawi
# City not found. Skipping...
# Processing Record 43 of Set 28 | najran
# Processing Record 44 of Set 28 | vyazemskiy
# Processing Record 45 of Set 28 | dudinka
# Processing Record 46 of Set 28 | moose factory
# Processing Record 47 of Set 28 | aguimes
# Processing Record 48 of Set 28 | machaneng
# Processing Record 49 of Set 28 | tagbilaran
# Processing Record 50 of Set 28 | rurrenabaque
# Processing Record 1 of Set 29 | nara
# Processing Record 2 of Set 29 | townsville
# Processing Record 3 of Set 29 | dawlatabad
# Processing Record 4 of Set 29 | ust-tsilma
# Processing Record 5 of Set 29 | gizo
# Processing Record 6 of Set 29 | caslav
# Processing Record 7 of Set 29 | synya
# Processing Record 8 of Set 29 | vilkija
# Processing Record 9 of Set 29 | yazykovo
# Processing Record 10 of Set 29 | ennis
# Processing Record 11 of Set 29 | bose
# Processing Record 12 of Set 29 | muisne
# Processing Record 13 of Set 29 | seoul
# Processing Record 14 of Set 29 | miri
# Processing Record 15 of Set 29 | paita
# Processing Record 16 of Set 29 | maues
# Processing Record 17 of Set 29 | nador
# Processing Record 18 of Set 29 | manzhouli
# Processing Record 19 of Set 29 | shumskiy
# Processing Record 20 of Set 29 | matamoros
# Processing Record 21 of Set 29 | mount gambier
# Processing Record 22 of Set 29 | akdepe
# Processing Record 23 of Set 29 | teloloapan
# Processing Record 24 of Set 29 | okhotsk
# Processing Record 25 of Set 29 | same
# Processing Record 26 of Set 29 | oranjemund
# Processing Record 27 of Set 29 | isangel
# Processing Record 28 of Set 29 | san jeronimo
# Processing Record 29 of Set 29 | preobrazheniye
# Processing Record 30 of Set 29 | pingliang
# Processing Record 31 of Set 29 | chiang mai
# Processing Record 32 of Set 29 | landskrona
# Processing Record 33 of Set 29 | srednekolymsk
# Processing Record 34 of Set 29 | beruwala
# Processing Record 35 of Set 29 | nanakuli
# Processing Record 36 of Set 29 | port hueneme
# Processing Record 37 of Set 29 | bargal
# City not found. Skipping...
# Processing Record 38 of Set 29 | watsa
# Processing Record 39 of Set 29 | popondetta
# Processing Record 40 of Set 29 | menongue
# Processing Record 41 of Set 29 | fort nelson
# Processing Record 42 of Set 29 | simao
# Processing Record 43 of Set 29 | takoradi
# Processing Record 44 of Set 29 | irtyshskiy
# Processing Record 45 of Set 29 | puerto baquerizo moreno
# Processing Record 46 of Set 29 | atagay
# Processing Record 47 of Set 29 | ust-nera
# Processing Record 48 of Set 29 | phrai bung
# City not found. Skipping...
# Processing Record 49 of Set 29 | felidhoo
# City not found. Skipping...
# Processing Record 50 of Set 29 | port pirie
# Processing Record 1 of Set 30 | midland
# Processing Record 2 of Set 30 | kuche
# City not found. Skipping...
# Processing Record 3 of Set 30 | wuzhou
# Processing Record 4 of Set 30 | ketchikan
# Processing Record 5 of Set 30 | ardistan
# City not found. Skipping...
# Processing Record 6 of Set 30 | tsabong
# Processing Record 7 of Set 30 | ugoofaaru
# Processing Record 8 of Set 30 | hornepayne
# Processing Record 9 of Set 30 | oranjestad
# Processing Record 10 of Set 30 | bergama
# Processing Record 11 of Set 30 | yazman
# Processing Record 12 of Set 30 | west bay
# Processing Record 13 of Set 30 | williston
# Processing Record 14 of Set 30 | porto novo
# Processing Record 15 of Set 30 | myaundzha
# Processing Record 16 of Set 30 | ostrovnoy
# Processing Record 17 of Set 30 | yatou
# Processing Record 18 of Set 30 | gulshat
# City not found. Skipping...
# Processing Record 19 of Set 30 | asfi
# Processing Record 20 of Set 30 | gasa
# Processing Record 21 of Set 30 | holiday
# Processing Record 22 of Set 30 | mosetse
# Processing Record 23 of Set 30 | emerald
# Processing Record 24 of Set 30 | vrangel
# Processing Record 25 of Set 30 | luwuk
# Processing Record 26 of Set 30 | leh
# Processing Record 27 of Set 30 | flinders
# Processing Record 28 of Set 30 | sioux lookout
# Processing Record 29 of Set 30 | discovery bay
# Processing Record 30 of Set 30 | bahir dar
# Processing Record 31 of Set 30 | iquique
# Processing Record 32 of Set 30 | senneterre
# Processing Record 33 of Set 30 | lafia
# Processing Record 34 of Set 30 | palmer
# Processing Record 35 of Set 30 | yiyang
# Processing Record 36 of Set 30 | olga
# Processing Record 37 of Set 30 | saleaula
# City not found. Skipping...
# Processing Record 38 of Set 30 | satitoa
# City not found. Skipping...
# Processing Record 39 of Set 30 | kamenskoye
# City not found. Skipping...
# Processing Record 40 of Set 30 | mazatan
# Processing Record 41 of Set 30 | kobojango
# City not found. Skipping...
# Processing Record 42 of Set 30 | anadyr
# Processing Record 43 of Set 30 | whitley bay
# Processing Record 44 of Set 30 | saint-leu
# Processing Record 45 of Set 30 | micoud
# Processing Record 46 of Set 30 | jiuquan
# Processing Record 47 of Set 30 | north bend
# Processing Record 48 of Set 30 | hervey bay
# Processing Record 49 of Set 30 | boyolangu
# Processing Record 50 of Set 30 | rock springs
# Processing Record 1 of Set 31 | sri aman
# Processing Record 2 of Set 31 | nishihara
# Processing Record 3 of Set 31 | mukhen
# Processing Record 4 of Set 31 | azle
# Processing Record 5 of Set 31 | linjiang
# Processing Record 6 of Set 31 | tessalit
# Processing Record 7 of Set 31 | pacific grove
# Processing Record 8 of Set 31 | chikwawa
# Processing Record 9 of Set 31 | springbok
# Processing Record 10 of Set 31 | ambon
# Processing Record 11 of Set 31 | mumford
# Processing Record 12 of Set 31 | kalanguy
# Processing Record 13 of Set 31 | el tigre
# Processing Record 14 of Set 31 | boende
# Processing Record 15 of Set 31 | nizhniy kuranakh
# Processing Record 16 of Set 31 | riyadh
# Processing Record 17 of Set 31 | roma
# Processing Record 18 of Set 31 | bagdarin
# Processing Record 19 of Set 31 | rundu
# Processing Record 20 of Set 31 | oneonta
# Processing Record 21 of Set 31 | beaverlodge
# Processing Record 22 of Set 31 | saint andrews
# Processing Record 23 of Set 31 | zeya
# Processing Record 24 of Set 31 | aksha
# Processing Record 25 of Set 31 | burkhala
# City not found. Skipping...
# Processing Record 26 of Set 31 | agva
# City not found. Skipping...
# Processing Record 27 of Set 31 | linz
# Processing Record 28 of Set 31 | kuito
# Processing Record 29 of Set 31 | slave lake
# Processing Record 30 of Set 31 | mugumu
# Processing Record 31 of Set 31 | zapolyarnyy
# Processing Record 32 of Set 31 | kitimat
# Processing Record 33 of Set 31 | amealco
# Processing Record 34 of Set 31 | umm jarr
# City not found. Skipping...
# Processing Record 35 of Set 31 | meghri
# Processing Record 36 of Set 31 | mvuma
# Processing Record 37 of Set 31 | mehran
# Processing Record 38 of Set 31 | vakhsh
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Avera  33.1940  -82.5271     72.55        71         100
# 1  Rabo De Peixe  37.8000  -25.5833     63.91        77          40
# 2      Busselton -33.6500  115.3333     58.73        71           0
# 3    Springfield  37.2153  -93.2982     49.89        60           0
# 4   Puerto Ayora  -0.7393  -90.3518     76.96        81          59
# 5          Roald  62.5833    6.1333     50.92        57           0
# 6    Antofagasta -23.6500  -70.4000     61.88        67          43
# 7           Foki  56.6930   54.3499     46.92        95          88
# 8          Kapaa  22.0752 -159.3190     73.72        85         100
# 9       Portland  45.5234 -122.6762     38.61        93         100
#
#    Wind Speed Country                 Date Current Description
# 0       10.96      US  2022-04-14 14:38:12     overcast clouds
# 1       11.50      PT  2022-04-14 14:38:13    scattered clouds
# 2        8.25      AU  2022-04-14 14:35:39           clear sky
# 3        9.22      US  2022-04-14 14:37:38           clear sky
# 4        9.89      EC  2022-04-14 14:38:13       broken clouds
# 5       16.11      NO  2022-04-14 14:38:14           clear sky
# 6        6.13      CL  2022-04-14 14:38:14    scattered clouds
# 7        3.85      RU  2022-04-14 14:38:15     overcast clouds
# 8        3.00      US  2022-04-14 14:35:53     overcast clouds
# 9        7.00      US  2022-04-14 14:36:34     overcast clouds

# %%
new_column_order = [ "City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness","Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0            Avera      US  33.1940  -82.5271     72.55        71         100
# 1    Rabo De Peixe      PT  37.8000  -25.5833     63.91        77          40
# 2        Busselton      AU -33.6500  115.3333     58.73        71           0
# 3      Springfield      US  37.2153  -93.2982     49.89        60           0
# 4     Puerto Ayora      EC  -0.7393  -90.3518     76.96        81          59
# ..             ...     ...      ...       ...       ...       ...         ...
# 716        Amealco      MX  20.1833 -100.1500     61.92        42         100
# 717         Meghri      AM  38.9029   46.2446     57.88        42          68
# 718          Mvuma      ZW -19.2792   30.5283     65.39        84          96
# 719         Mehran      IR  33.1222   46.1646     85.15        11          85
# 720         Vakhsh      TJ  37.7149   68.8346     73.62        43           0
#
#      Wind Speed Current Description
# 0         10.96     overcast clouds
# 1         11.50    scattered clouds
# 2          8.25           clear sky
# 3          9.22           clear sky
# 4          9.89       broken clouds
# ..          ...                 ...
# 716        2.48     overcast clouds
# 717        2.89       broken clouds
# 718        6.38          light rain
# 719       13.02     overcast clouds
# 720        2.24           clear sky
#
# [721 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
